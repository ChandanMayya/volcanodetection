# %%
import cv2
import os
import keras
from pathlib import Path

# %%
import numpy as np
CATEGORIES = ['eruption', 'no_eruption']

# %%
def image(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    new_arr = cv2.resize(img, (120, 120))
    new_arr = np.array(new_arr)
    new_arr = new_arr.reshape(-1, 120, 120, 1)
    return new_arr

model = keras.models.load_model('3x3x64-volcano.model')

# %%
prediction = model.predict([image('C:/Users/User/OneDrive/Desktop/OnBoardVolcanicEruptionDetection-main/validation/eruption/LE07_167049_20071015.png')])
print(CATEGORIES[prediction.argmax()])
# Out:
# 1/1 [==============================] - 0s 408ms/step
# eruption

# %%
DIRECTORY = r'C:\Users\User\OneDrive\Desktop\OnBoardVolcanicEruptionDetection-main\data_reviewed\training'
CATEGORIES = ['eruption/', 'no_eruption/']
output=[]
for category in CATEGORIES:
    path = os.path.join(DIRECTORY, category)
    for img in os.listdir(path):
        img_path = os.path.join(path, img)
        
        prediction = model.predict([image(img_path)])
        output.append(CATEGORIES[prediction.argmax()])
        print(CATEGORIES[prediction.argmax()])
        print(img_path)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# eruption/
# C:\Users\User\OneDrive\Desktop\OnBoardVolcanicEruptionDetection-main\data_reviewed\training\eruption/20151216T160652_20151216T161917_T16PEU.png
# 1/1 [==============================] - 0s 53ms/step
# eruption/
# C:\Users\User\OneDrive\Desktop\OnBoardVolcanicEruptionDetection-main\data_reviewed\training\eruption/20160727T004116_20160727T040428_T56UPA.png
# 1/1 [==============================] - 0s 44ms/step
# eruption/
# C:\Users\User\OneDrive\Desktop\OnBoardVolcanicEruptionDetection-main\data_reviewed\training\eruption/20160914T063512_20160914T063506_T40KCB.png
# 1/1 [==============================] - 0s 47ms/step
# eruption/
# C:\Users\User\OneDrive\Desktop\OnBoardVolcanicEruptionDetection-main\data_reviewed\training\eruption/20161003T221602_20161003T231920_T60HWD.png
# 1/1 [==============================] - 0s 33ms/step
# eruption/
# ...
